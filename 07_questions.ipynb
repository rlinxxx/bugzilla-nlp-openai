# %% [markdown]
# # Question answering using embeddings-based search
#
# <u><b>Full procedure<b><u>
#
# 1. Prepare search data (once per document)
#
# - Collect: We'll download a few hundred bug reports
# - Chunk: Documents are split into short, mostly self-contained sections to be embedded
# - Embed: Each section is embedded with the OpenAI API
# - Store: Embeddings are saved (for large datasets, use a vector database)
#
# 2. Search (once per query)
#
# - Given a user question, generate an embedding for the query from the OpenAI API
# - Using the embeddings, rank the text sections by relevance to the query
#
# 3. Ask (once per query)
#
# - Insert the question and the most relevant sections into a message to GPT
# - Return GPT's answer
#
# 4. Answers
# - Some example questions are made to the system
# - The bug reports in which the answers are found can also be retrieved

# %% [markdown]
# ### Imports and Read Data

# %%
import ast  
from scipy import spatial  
import pandas as pd 

from openai import OpenAI
import tiktoken 

# Create a list of models 
GPT_MODELS = ["gpt-4o", "gpt-4o-mini"]
# Embedding models
EMBEDDING_MODEL = "text-embedding-3-small"

client = OpenAI()

# %%
# Retrieve the bug reports from the request_data notebook
data_path = "bug_reports_mozilla_firefox_resolved_fixed_comments_embeddings.csv"

# The embeddings are already stored in the CSV, and need to be transformed from strings to lists
data = pd.read_csv(data_path)
data["Embeddings"] = data["Embeddings"].apply(ast.literal_eval)

# %% [markdown]
# ### Search
#
# Now we'll define a search function that:
#
# - Takes a user query and a dataframe with text & embedding columns
# - Embeds the user query with the OpenAI API
# - Uses distance between query embedding and text embeddings to rank the texts
# - Returns two lists:
# 1. The top N texts, ranked by relevance
# 2. Their corresponding relevance score

# %%
# Search function
def strings_ranked_by_relatedness(
    query: str,
    data: pd.DataFrame,
    relatedness_fn = lambda x, y: 1 - spatial.distance.cosine(x, y),
    top_n: int = 100
) -> tuple[list[str], list[float]]:
    
    """Returns a list of strings and relatednesses, sorted from most related to least."""
    query_embedding_response = client.embeddings.create(
        model = EMBEDDING_MODEL,
        input = query,
    )
    query_embedding = query_embedding_response.data[0].embedding
    strings_and_relatednesses = [
        (row["Concat"], relatedness_fn(query_embedding, row["Embeddings"]))
        for i, row in data.iterrows()
    ]
    strings_and_relatednesses.sort(key = lambda x: x[1], reverse = True)
    strings, relatednesses = zip(*strings_and_relatednesses)
    
    return strings[:top_n], relatednesses[:top_n]

# %%
# Examples
strings, relatednesses = strings_ranked_by_relatedness("User Interface (UI)", data, top_n = 5)
for string, relatedness in zip(strings, relatednesses):
    print(f"{relatedness = :.3f}")
    display(string)
    print("\n")
# Out:
# relatedness = 0.510
# 'summary provide access fxa device management ui description this meta bug track bug block on u get manage device ui while ui almost certainly live on server need exist way client can deliver require ux'
# relatedness = 0.473
# 'summary web base stub install ui description current stub install user interface code highly fragile error prone difficult modify difficult read the number engineer available work on worrying small extremely difficult bring new engineer code specialized replace current implement web page render native web view make modify ui visual design much fast easy specialist engineer would no long need make change change can made frequent less risk it would also remove lot limit current exist on ui element may use can custom note current web base mean use html css not actually downloade ui element web runtime'
# relatedness = 0.443
# 'summary initial payment request basic credit card add edit page description share logic ui preference management ui'
# relatedness = 0.434
# 'summary crash user interface update description track bug the current crash user interface problem need fixed the problem fix list track bug this bug cover implement user interface change this mock new user interface'
# relatedness = 0.425
# 'summary login identify secure internal ui page description login brand logo address bar identity box show secure internal ui page'

# %% [markdown]
# ### Ask
#
# With the search function above, we can now automatically retrieve relevant knowledge and insert it into messages to GPT. Below, we define a function ask that:
#
# - Takes a user query
# - Searches for text relevant to the query
# - Stuffs that text into a message for GPT
# - Sends the message to GPT
# - Returns GPT's answer

# %%
def num_tokens(text: str, model: str = GPT_MODELS[0]) -> int:
    
    """Return the number of tokens in a string."""
    
    encoding = tiktoken.encoding_for_model(model)
    
    return len(encoding.encode(text))

# %%
def query_message(
    query: str,
    data: pd.DataFrame,
    model: str,
    token_budget: int
) -> str:
    
    """Return a message for GPT, with relevant source texts pulled from a dataframe."""
    
    strings, relatednesses = strings_ranked_by_relatedness(query, data)
    introduction = 'Use the bug reports from Bugzilla to answer the subsequent question. If the answer cannot be found, write "I could not find an answer."'
    question = f"\n\nQuestion: {query}"
    message = introduction
    
    for string in strings:
        next_bug = f'\n\nBug Report Summary:\n"""\n{string}\n"""'
        if (
            num_tokens(message + next_bug + question, model = model)
            > token_budget
        ):
            break
        else:
            message += next_bug
            
    return message + question

# %%
def ask(
    query: str,
    data: pd.DataFrame = data,
    model: str = GPT_MODELS[0],
    token_budget: int = 4096 - 500,
    print_message: bool = False,
) -> str:
    
    """Answers a query using GPT and a dataframe of relevant texts and embeddings."""
    
    message = query_message(query, data, model = model, token_budget = token_budget)
    
    if print_message:
        print(message)
        
    messages = [
        {"role": "system", "content": "You answer questions about the Bugzilla bug reports"},
        {"role": "user", "content": message},
    ]
    response = client.chat.completions.create(
        model = model,
        messages = messages,
        temperature = 0
    )
    response_message = response.choices[0].message.content
    
    return response_message

# %% [markdown]
# ### Answers

# %%
print(ask('What is the most common issue in these bug reports?'))
# Out:
# The most common issue in these bug reports appears to be related to crashes and performance problems. Several reports mention crashes, such as "crash description this bug crash report" and "crash on machine code landed bug maybe fission related crash report." Additionally, there are reports of performance issues, such as "activitysteam screenshott appear hang main process multiple second apparently after visiting link" and "investigate decide manage alpenglow performance." These types of issues seem to be a recurring theme across multiple reports.

# %%
print(ask('What are the issues related to User Interface (UI) in these bug reports?'))
# Out:
# The bug reports related to User Interface (UI) issues include:
#
# 1. Crash in the user interface during updates and changes (first bug report).
# 2. Applying UX design to translate popups (second bug report).
# 3. Improving UI for page block policy (fifth bug report).
# 4. Removing pre-Firefox UI migration steps (sixth bug report).
# 5. Fixing CustomizableUI failures in showing the Proton toolbar (tenth bug report).
# 6. Simplifying PanelUI show and adding tests for opening and closing the main menu (eleventh bug report).
# 7. Providing access to FxA device management UI (thirteenth bug report).
# 8. Updating preference UI for Firefox to suggest best match (fifteenth bug report).
# 9. Improving toolbar customization on OS (seventeenth bug report).
# 10. Removing old UI migration steps (eighteenth bug report).
# 11. Updating translate popup icon with UX recommended treatment (nineteenth bug report).
# 12. Addressing incorrect display of the "Share Select Device" button (twenty-first bug report).
# 13. Hiding the tabstrip toolbar to allow the nav bar and title bar to use vertical tabs (twenty-second bug report).
# 14. Migrating XUL preference subdialog (twenty-third bug report).
# 15. Updating remaining OS textbox focus style (twenty-sixth bug report).
# 16. Addressing the issue of torn-off tabs not opening on screen drag (twenty-seventh bug report).
# 17. Removing bookmark description UI (thirty-fifth bug report).
# 18. Improving upon engagement with Firefox Suggest experiment variation opt dialog (forty-fourth bug report).
# 19. More accessible fix-ups for screen readers (fifty-seventh bug report).
# 20. Migrating window title to Fluent (fifty-eighth bug report).
# 21. Implementing device share animation on background tabs (sixty-seventh bug report).
#
# These reports highlight various UI-related issues, including design updates, migration steps, accessibility improvements, and specific UI component behaviors.

# %%
print(ask('What are the issues related to User Interface (UI) in these bug reports?', print_message = True))
# Out:
# Use the bug reports from Bugzilla to answer the subsequent question. If the answer cannot be found, write "I could not find an answer."
#
# Bug Report Summary:
# """
# summary crash user interface update description track bug the current crash user interface problem need fixed the problem fix list track bug this bug cover implement user interface change this mock new user interface
# """
#
# Bug Report Summary:
# """
# summary apply ux design translate popup description this bug track follow work strict apply feedback on design popup ui see bug initial prototype
# """
#
# Bug Report Summary:
# """
# summary bug followup apply searchbar add engine overflow menu css change window linux description this bug initially create clone bug
# """
#
# Bug Report Summary:
# """
# summary bugzilla component uriloader incorrect mot yaml description the bugzilla component uriloader state core document navigation state correct component firefox file handle
# """
#
# Bug Report Summary:
# """
# summary improve ui page block policy description the page display bug mechanism block page meant placeholder final ui this bug address update ui
# """
#
# Bug Report Summary:
# """
# summary remove pre firefox ui migration step description this bug initially create clone bug
# """
#
# Bug Report Summary:
# """
# summary enable window osx rtl user description bug block bug bug block work originally landed bug bug
# """
#
# Bug Report Summary:
# """
# summary remove redundant gurlbar startlayoutextend call focusandselecturlbar description bug made redundant
# """
#
# Bug Report Summary:
# """
# summary add fluent ftl support customizableui widget creation description we need bug bug
# """
#
# Bug Report Summary:
# """
# summary fix customizableui failure show enabling proton toolbar description see most failure customizableui test
# """
#
# Bug Report Summary:
# """
# summary simplify panelui show add test help open close main menu description see bug comment
# """
#
# Bug Report Summary:
# """
# summary ui punchlist getusermedia block description item resolve relate ui either ff uplift aurora soon thereafter bug block need backend first
# """
#
# Bug Report Summary:
# """
# summary provide access fxa device management ui description this meta bug track bug block on u get manage device ui while ui almost certainly live on server need exist way client can deliver require ux
# """
#
# Bug Report Summary:
# """
# summary increase urlbar min width description this bug initially create clone bug bug block ux verdi mconnor ux team evaluate relative importance toolbar item in meantime increase urlbar min width modify flex value make urlbar useful small window width one goal patch preserve search bar toolbar window width px user four toolbar item left urlbar this accommodate user vertical tile window on px wide display
# """
#
# Bug Report Summary:
# """
# summary update preference ui firefox suggest best match description this week discussion providing simple opt out preference ui best match the ui still early plan stage jira ticket this bug track implement work ui spec complete
# """
#
# Bug Report Summary:
# """
# summary figure out bug making browse urlbarinput tooltip j fail on window description in bug disabled browse component urlbar test browse browse urlbarinput tooltip j strange perma failure on window this bug enable
# """
#
# Bug Report Summary:
# """
# summary improve toolbar custom ue on os description improve toolbar custom ue on os file ff do version bug
# """
#
# Bug Report Summary:
# """
# summary remove old ui migration step description this bug initially create clone bug cleanup time
# """
#
# Bug Report Summary:
# """
# summary update translate popup icon ux recommend treatment description the ui need give indication page translate ux specific feedback on work bug track work
# """
#
# Bug Report Summary:
# """
# summary ctrl mouse wheel zoom zoom quick description see issue report
# """
#
# Bug Report Summary:
# """
# summary share select device button incorrect display description screenshot latest nightly latest aurora firefox beta firefox ubuntu open firefox navitgate website require permission click join observe notification doorhanger there no ui issue doorhanger correct display the dropdown marker display part button share select device above button this not recent regress also reproduce on firefox window os mac os not affected issue
# """
#
# Bug Report Summary:
# """
# summary hide tabstrip toolbar allow nav bar titlebar use vertical tab description the second part bug hide tab toolbar move red yellow green window control nav toolbar per we need make sure look okay across platform don think bug dependent on bug probably worth check sfoster
# """
#
# Bug Report Summary:
# """
# summary migrate xul preference subdialog description xul part bug
# """
#
# Bug Report Summary:
# """
# summary nimbus rollout keep enabling hover preview description steps reproduce some user report firefox keep reset browse tab hoverpreview enable not affected issue please investigate cause
# """
#
# Bug Report Summary:
# """
# summary update remain os textbox focus style description this bug initially create clone bug some text field still pre yosemite glowy effect get flatter different blue see bug example generally boil down add medium query copy style update box shadow appropriate alternative may possible use css variable make whole thing slightly less repetition wide range selector not entire sure feasible general case list edit bookmark panel input box folder tree tag selector tabbrowser tab focus ring in toolkit xul link style notification button style second time notification button style input edit tree
# """
#
# Bug Report Summary:
# """
# summary torn off tab no long open on screen drag description this bug initially create clone bug in bug patch landed the first one fixed main issue bug fix secondary issue observe however still seeing issue doesn actually appear expect drop location those additional patch back out cause regress this bug follow bug get patch relande
# """
#
# Bug Report Summary:
# """
# summary back out bug beta bug description per bug comment
# """
#
# Bug Report Summary:
# """
# summary regress no hover feedback go search dropdown button description see bug comment
# """
#
# Bug Report Summary:
# """
# summary follow fix allow user choose whether search suggestion history suggestion come first address bar description this bug initially create clone bug the fix bug broken case upgrade firefox urlbar not unify the expect behavior bookmark history appear search suggestion actual behavior opposite the problem customizableui getplacementofwidget return null call migration code nsbrowserglue course point cui finished setting initial window
# """
#
# Bug Report Summary:
# """
# summary add marionette test coverage new private browse ui search description in bug disabled new ui existing marionette test would pas we write new test new ui
# """
#
# Bug Report Summary:
# """
# summary breakdown improve sync error state surface ui description this bug breakdown moving sync error notification hamburger menu this also involve investigate might showing error infobar
# """
#
# Bug Report Summary:
# """
# summary download panel footer overlap panel border description this bug initially create clone bug bug take care window os
# """
#
# Bug Report Summary:
# """
# summary issue arithmetic pdf form description user agent mozilla gecko firefox steps reproduce see github issue
# """
#
# Bug Report Summary:
# """
# summary crash description this bug crash report bp df ec ac ac top frame crashing thread libxul mozilla ipc processlink sendmessage ipc glue messagelink cpp libxul mozilla ipc messagechannel send ipc glue messagechannel cpp libxul mozilla dom pwindowglobalchild sendrawmessage ipc ipdl pwindowglobalchild cpp libxul mozilla dom jswindowactorchild sendrawmessage dom ipc jswindowactorchild cpp libxul mozilla dom jswindowactor queryhandler sendrep dom ipc jswindowactor cpp libxul mozilla dom jswindowactor queryhandler resolvedcallback dom ipc jswindowactor cpp libxul mozilla dom dom promise promise cpp libxul mozilla dom nativehandlercallback dom promise promise cpp libxul j internalcallorconstruct j src vm interpreter cpp libxul promisereactionjob j src builtin promise cpp the raw crash reason moz crash all platform seem affected
# """
#
# Bug Report Summary:
# """
# summary port fix bug description when port resize handler popup port fix bug bug still need resize handler probably urlbar not focus though
# """
#
# Bug Report Summary:
# """
# summary bug followup address reliability paveover install problem description several issue bug patch cause back out bug those issue need address
# """
#
# Bug Report Summary:
# """
# summary issue place ui button description the place ui button look odd cannot remove fix quick
# """
#
# Bug Report Summary:
# """
# summary change re enable add on compat check default update firefox description base on recent discussion look like don want disable add on compat update option default this bug pref change can uplift aurora the benefit can fix default everywhere since metro enable ui wrong
# """
#
# Bug Report Summary:
# """
# summary reduce margin address bar menu button popup window description followup bug
# """
#
# Bug Report Summary:
# """
# summary remove bookmark description ui description per bug remove description ui bookmark this bug remove front end part bug deal back end cleanup release later ui remove
# """
#
# Bug Report Summary:
# """
# summary focus urlbar search suggestion opt dismiss after pressing opt accesskey description create attachment patch this bug initially create clone bug notice after bug landed focus urlbar whenever suggest search pref change not exactly right that mean whenever toggle related checkbox search pref pane location bar get focus wrong should focus onclick handler button test patch manual doe work right
# """
#
# Bug Report Summary:
# """
# summary unescapeuriforui may slow on long data uri cause jank on searching urlbar description chutten report bug today on slack there open tab long data uri searching open tab gfx cause jank not return open tab see profile the problem unescapeuriforui call payloadandsimplehighlights use unescapeuriforui part urlbar it would useful check can avoid excessive long uri pass everywhere since likely use present url user rather actually load may want urlbarutil unescapeuriaslabel wrapper limit string passing unescapeuriforui we no ui showing thousand char
# """
#
# Bug Report Summary:
# """
# summary main menu entry lose padding on mousedown description create attachment screenshot png debian test kde xorg mozregression good bad info last good revision eb da aefabe eb adadc info first bad revision bc fe fe info pushlog bc gottwald bug port url overflow handle urlbarbind xml urlbarinput jsm standard ff fad gottwald bug load toolbarbutton cs scrollbox cs document stylesheet paolo
# """
#
# Bug Report Summary:
# """
# summary lazy report anti track notification front end description for similar reason bug
# """
#
# Bug Report Summary:
# """
# summary update metadata layout xul file not point frontend component like firefox menu description say file bug component file bug component this use point core product stuff got change xp toolkit widget menu stop existing the firefox menu component meant issue actual content menu firefox not xul layout implement people monitor don lot experience bit code don really mind core xul core layout something like neil emilio strong preference
# """
#
# Bug Report Summary:
# """
# summary issue device sync tab description collect device related issue meta bug can track
# """
#
# Bug Report Summary:
# """
# summary blurry menubar ubuntu unity firefox developer edition description this bug rip out bug use mozregression good bad repo mozilla aurora eventually settled pushlog so pushlog pretty big
# """
#
# Bug Report Summary:
# """
# summary investigate impact pingcentre dataloss issue description this placeholder bug help bugzy view reflect current work it track work happening mostly elsewhere
# """
#
# Bug Report Summary:
# """
# summary doorhanger anchor highlight show big area click description create attachment key focus mp use ubuntu window mac start firefox access login form input text password login form focus away highlight grey key permission pannel highlight grey key click exactly on key focus away highlight grey key click towards corner highlight there click animation password message pannel open there click animation password message pannel not open in case password permission pannel open althought fix bug make issue lot visible give impression permission dismiss doorhanger icon doesn always work impression old deep issue towards end screencast focus move grey icon toward security icone highlight remains on dismiss password icon highlight encapsulate icon separate bug can log issue need seem somehow issue bug debug found commit message bug trigger highlight hover over notification icon johannh pbz differential revision
# """
#
# Bug Report Summary:
# """
# summary replace cu reporter call browsercontenthandler description we working towards remove cu reporter preference standard console error this bug browsercontenthandler
# """
#
# Bug Report Summary:
# """
# summary avoid use ui popup disable autohide pref browse unitconversion j test description we enable ui popup disable autohide browse unitconversion j test avoid timeout happen wait showing popup however enabling pref might change behavior better disable ideally disable bug as hint made test run on new window resolve test failure bug it may fix issue well
# """
#
# Bug Report Summary:
# """
# summary more from mozilla xul html refactor description scope bug simplify refactor more from mozilla xhtml remove xul dependency implement ui html update related style current implement
# """
#
# Bug Report Summary:
# """
# summary analyze ui telemetry sync tab menu panel sidebar description this bug initially create clone bug the user story attachment bug describe artifact wish measure sync tab ui that bug landed telemetry measurement bug analyze telemetry produce request artifact ilana still able help u anything need u help get start note nightly build last day report data might enough get start even enough produce valid data yet thanks
# """
#
# Bug Report Summary:
# """
# summary remove pointless not selector urlbarview description just leftover bug
# """
#
# Bug Report Summary:
# """
# summary remove vertical padding titlebar buttonbox description this padding make bug bug worse
# """
#
# Bug Report Summary:
# """
# summary ensure select translate focus highlight sufficient mvp description description this bug track progress on ensure default focus highlight element correct select translate panel
# """
#
# Bug Report Summary:
# """
# summary to improve upon engagement firefox suggest experiment variation opt dialog description this meta bug qa team track issue found test effort this meta bug also use track internal team metric closed request sign off for information please reach out bug reporter team via
# """
#
# Bug Report Summary:
# """
# summary check pref except site preference show confuse ui description seen running mozilla gecko namoroka pre str open tool clear recent history item checked except site preference note ui show all history clear this action cannot undone bug indicate not correct
# """
#
# Bug Report Summary:
# """
# summary firefox track description track feature bug not contained within firefox bugzilla component block
# """
#
# Bug Report Summary:
# """
# summary investigate decide manage alpenglow performance description this bug initially create clone bug in bug landed new theme enabling new theme welcome flow can cause visual flash titlebar we need figure out much problem think on mac somewhat notice on linux vm test fairly notice however noticeable comparison since theme render slow enough one visibly watch render on window vm test three slow stand out much unless knew exactly look forward profile lgreco made on linux there bunch interesting stuff look like lot code execution layout javascript though compositor bunch wait may play we speculate extra image color adjust gradient svg involved problem next step probably include check out on reference machine possibly timing profile play around theme property see low hanging fruit we may want take video
# """
#
# Bug Report Summary:
# """
# summary intermittent browse newtabmessage j received expect number history item got expect description related bug intermittent test failure occur on window
# """
#
# Bug Report Summary:
# """
# summary ux improvement swipe navigation description in bug go tweak icon not go fancy page change
# """
#
# Bug Report Summary:
# """
# summary preference migrate root xul window element html html element description similar bug change dom preference xul window linkset html link script linkset content window html head link script head body content body html this get u proper box model highlight devtool working on preference also good test case surface issue given amount test coverage preference page
# """
#
# Bug Report Summary:
# """
# summary close horizontal tab stutter towards end animation description as title say close horizontal tab stutter towards end like linger around sudden disappear instead animate properly it fairly visible close tab two tab mozgression point bug fix vertical tab min width desktop theme reviewer tabbrowser reviewer sidebar reviewer nsharpley sfoster mconley differential revision this happen on linux window
# """
#
# Bug Report Summary:
# """
# summary handle request change updatewith verify state stay consistent description this bug track audit dialog behaviour ensure dialog state remains consistent payment request change bug one example could problem possibly other
# """
#
# Bug Report Summary:
# """
# summary more accessible fix ups screen reader description very recent landing introduce number new issue see bug visual one also panel scream browse via screen reader reading browse mode command so address all panel role document not there enough information textual form not part control make sense give screen reader user ability browse familiar reading command consequently make label aria heading can navigate easily the new info button missing accessible label patch work
# """
#
# Bug Report Summary:
# """
# summary migrate window title fluent sequel description in bug migrate main firefox window title fluent in bug revert due talo regress on tabswitch gij suggest bug may better solution port away dtd may give u acceptable performance
# """
#
# Bug Report Summary:
# """
# summary allow uitour check set firefox default browse description window make hard set default browse instead click button within firefox user must perform sequence step native window dialog firefox no control over one idea help sumo page help guide user though ui series screenshot it would probably helpful page ability trigger opening new window dialog while immediate focus dealing new ui on window maybe want allow on platform also think implication mean expose firefox default browse not uitour know offer not see also bug
# """
#
# Bug Report Summary:
# """
# summary stg step ui migration description bring html layout support stg this patch not change current user ui tab grouping pref turn off add additional element support stg grouping build out
# """
#
# Bug Report Summary:
# """
# summary external bug webextension depend on description way not loose technology bug webextension need handle team
# """
#
# Bug Report Summary:
# """
# summary update preference org according proposal may th description there new proposal improve current preference design what propose new heading level improve clarity move section across panel ux feel strong want ship improve version instead bug it sound do spec can finalize on time the alternative would bug move design future version this bug represent engineering work involved any bug found bug would need reevaluation after implement design block bug
# """
#
# Bug Report Summary:
# """
# summary window default mailto handler experiment description this meta bug qa team track issue found test effort this meta bug also use track internal team metric closed request sign off for information please reach out bug reporter team via
# """
#
# Bug Report Summary:
# """
# summary require user interaction push notification permission prompt nightly description this temporary experiment gauge result user experience breakage please file breakage bug block bug
# """
#
# Bug Report Summary:
# """
# summary implement device share animation on background tab description this implement bug last point user story bug if user leaf tab tab fav icon get replace red permission icon animate fav icon red icon long camera mic session open see bug comment propose ux
# """
#
# Question: What are the issues related to User Interface (UI) in these bug reports?
# The bug reports related to User Interface (UI) issues include:
#
# 1. Crash in the user interface during updates and changes (first bug report).
# 2. Applying UX design to translate popups (second bug report).
# 3. Improving UI for page block policy (fifth bug report).
# 4. Removing pre-Firefox UI migration steps (sixth bug report).
# 5. Fixing CustomizableUI failures in showing the Proton toolbar (tenth bug report).
# 6. Improving toolbar customization on OS (sixteenth bug report).
# 7. Updating the translate popup icon with UX recommended treatment (eighteenth bug report).
# 8. Incorrect display of the "Share Select Device" button (twentieth bug report).
# 9. Hiding the tabstrip toolbar to allow the nav bar in the titlebar for vertical tabs (twenty-first bug report).
# 10. Updating remaining OS textbox focus style (twenty-fourth bug report).
# 11. Issue with the placement of UI buttons (thirty-second bug report).
# 12. Removing bookmark description UI (thirty-sixth bug report).
# 13. UnescapeURIFOrUI causing jank on searching in the URL bar (thirty-eighth bug report).
# 14. Main menu entry losing padding on mousedown (thirty-ninth bug report).
# 15. Doorhanger anchor highlight showing a big area on click (forty-second bug report).
# 16. Avoiding the use of UI popups to disable autohide pref in tests (forty-fifth bug report).
# 17. Analyzing UI telemetry for sync tab menu panel sidebar (forty-seventh bug report).
# 18. Blurry menubar on Ubuntu Unity in Firefox Developer Edition (fifty-second bug report).
# 19. UX improvement for swipe navigation (sixty-first bug report).
# 20. Close horizontal tab stutter towards the end of animation (sixty-seventh bug report).
# 21. More accessible fixes for screen readers (seventieth bug report).
# 22. Updating preference UI according to a new proposal (seventy-seventh bug report).
#
# These reports highlight various UI-related issues, including design updates, customization improvements, accessibility enhancements, and specific UI element behaviors.

# %%
print(ask("About what the issues related to Firefox web browser talk about?"))
# Out:
# The issues related to the Firefox web browser discussed in the bug reports include:
#
# 1. New panel features and design documentation.
# 2. Security issues and emergency bulletins.
# 3. Migration from 32-bit to 64-bit Firefox versions.
# 4. Improvements in tab browsing.
# 5. Crashes when accessing download options.
# 6. New profile welcome messages and user engagement.
# 7. Localization information for Firefox updates.
# 8. Vulnerabilities in Firefox add-ons and potential exploits.
# 9. Updates and redirection for Firefox view code.
# 10. Design updates for welcome back pages.
# 11. Availability of Firefox Labs outside the Nightly train.
# 12. Issues with bookmarks not leading to themes or extensions.
# 13. Branding changes for Firefox Beta.
# 14. Updates to default theme information.
# 15. Transition plans for enabling Firefox Translate.
# 16. Issues with clean branch builds and first page loading.
# 17. Enabling Firefox View Next by default in Nightly builds.
# 18. UI issues with URL bar and search dropdowns.
# 19. Problems with drag-and-drop in bookmarks.
# 20. Recommendations for using NSS SDB with network filesystems.
# 21. Arithmetic issues in PDF forms.
# 22. New Linux package testing for Firefox desktop.
# 23. RTL issues in URL dropdown lists.
# 24. Initial architecture for Firefox Translate.
# 25. Firefox client tracking.
# 26. Download dialog box freezing issues.
# 27. New dialog notification settings under Firefox preferences.
# 28. User onboarding experiments.
# 29. Issues with restoring discarded tabs.
# 30. Inconsistent user experience with DNS and location bar entries.
# 31. Fallback solutions for GMP downloads.
# 32. Default values for target URI in Fluent variables.
# 33. Persistent Firefox Sync advertisements.
# 34. Opening downloaded files in Firefox.
# 35. Nonfunctional menu items when tools are focused.
# 36. Implementing a "copy link to highlight" feature.
# 37. Main thread jank issues with Firefox View.
# 38. Non-responsive behavior in Firefox Nightly.
# 39. Blurry menubar issues on Ubuntu Unity.
# 40. Documentation updates for new tab messages.
# 41. Tracking features and bugs in Firefox.
# 42. Issues with favicon clicks not selecting URLs.
# 43. Startup crashes in new Firefox installations.
# 44. Creating landing pages for Firefox Monitor and Send.
# 45. Increased request volume on Firefox startup.
# 46. Implementing recent search history in the URL bar.
# 47. Upgrading NSS to fix security bugs.
# 48. Publishing welcome messages using the moment system.
#
# These issues cover a wide range of topics, including security, performance, user interface, feature enhancements, and localization.

# %%
print(ask("What are the most common software components affected?"))
# Out:
# Based on the provided bug report summaries, the most common software components affected include:
#
# 1. **XUL (XML User Interface Language)** - Mentioned in several reports related to crashes and layout issues.
# 2. **NSI (Nullsoft Scriptable Install System)** - Referenced in installation-related bugs.
# 3. **IPC (Inter-Process Communication)** - Involved in crash reports.
# 4. **JavaScript Modules (JSM)** - Referenced in performance and startup issues.
# 5. **Lodash** - Mentioned in reports about vulnerabilities and dependency updates.
# 6. **Telemetry** - Involved in reports about message impression and sync preferences.
# 7. **Sync Engine** - Referenced in reports about sync errors and preferences.
#
# These components appear frequently across different bug reports, indicating they are commonly affected in various issues.

# %%
print(ask("What are the most common features affected?"))
# Out:
# I could not find an answer.

# %%
print(ask("What words are used the most to describe the issues?"))
# Out:
# The words most frequently used to describe the issues in the Bugzilla bug reports are:
#
# 1. Description
# 2. Bug
# 3. Issue
# 4. Summary
# 5. Fix
# 6. Update
# 7. String
# 8. Preference
# 9. Telemetry
# 10. Improve
#
# These words are commonly associated with the nature of bug reports, which typically involve describing issues, proposing fixes, and updating or improving software components.
